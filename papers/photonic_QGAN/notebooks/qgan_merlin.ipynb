# %%
import shutil
import json
import os
import torch
import numpy as np
import perceval as pcvl
import torchvision.transforms as transforms

from torch.utils.data import RandomSampler
#from tqdm.notebook import tqdm
from tqdm.auto import tqdm

import sys; sys.path.insert(0, '..')
from lib.qgan import QGAN
from utils.data import DigitsDataset

# %%
# definitions and constants
image_size = 8
batch_size = 4
lossy = False
write_to_disk = True

# optimization params
opt_iter_num = 1500
lrD = 0.002
lrG = 0.002
opt_params={"opt_iter_num": opt_iter_num, }

# %%
# define desired run configurqtions
arch_grid_45modes = [
    {
        "noise_dim": 1,
        "arch": ["var", "enc[2]", "var"],
    },
    {
        "noise_dim": 1,
        "arch": ["var", "var", "enc[2]", "var", "var"]
    },
    {
        "noise_dim": 2,
        "arch": ["var", "enc[1]", "var", "enc[3]", "var"],
    },
    {
        "noise_dim": 2,
        "arch": ["var", "var", "enc[1]", "var", "var", "enc[3]", "var", "var"],
    }
]

input_grid_4modes = [
    {
        "input_state": [1, 1, 1, 1],
        "gen_count": 2,
        "pnr": True
    },
    {   
        "input_state": [1, 1, 1, 1],
        "gen_count": 4,
        "pnr": False
    },
    {
        "input_state": [1, 0, 1, 1],
        "gen_count": 4,
        "pnr": True
    },
]

arch_grid_5modes = [
    {
        "noise_dim": 3,
        "arch": ["var", "enc[0]", "var", "enc[2]", "var", "enc[4]", "var"],
    }
]

input_grid_5modes = [
    {
        "input_state": [0, 1, 0, 1, 0],
        "gen_count": 4,
        "pnr": False
    },
    {
        "input_state": [1, 0, 1, 0, 1],
        "gen_count": 2,
        "pnr": True
    }
]


arch_grid_8modes = [
    {
        "noise_dim": 1,
        "arch": ["var", "enc[4]", "var"],
    },
    {
        "noise_dim": 1,
        "arch": ["var", "var", "enc[4]", "var", "var"]
    },
    {
        "noise_dim": 2,
        "arch": ["var", "enc[2]", "var", "enc[5]", "var"],
    },
    {
        "noise_dim": 2,
        "arch": ["var", "var", "enc[2]", "var", "var", "enc[5]", "var", "var"],
    },
    {
        "noise_dim": 3,
        "arch": ["var", "enc[1]", "var", "enc[4]", "var", "enc[6]", "var"],
    },
    {
        "noise_dim": 4,
        "arch": ["var", "enc[1]", "var", "enc[3]", "var", "enc[5]", "var", "enc[7]", "var"],
    },
]

input_grid_8modes = [
    {
        "input_state": [0, 0, 1, 0, 0, 1, 0, 0],
        "gen_count": 2,
        "pnr": False
    }
]

config_grid = []

'''
for inp in input_grid_5modes:
    for arch in (arch_grid_45modes + arch_grid_5modes):
        config = inp.copy()
        config.update(arch)
        config_grid.append(config)

for inp in input_grid_4modes:
    for arch in arch_grid_45modes:
        config = inp.copy()
        config.update(arch)
        config_grid.append(config)
        
for inp in input_grid_8modes:
    for arch in arch_grid_8modes:
        config = inp.copy()
        config.update(arch)
        config_grid.append(config)
'''

for inp in input_grid_5modes:
    for arch in (arch_grid_5modes):
        config = inp.copy()
        config.update(arch)
        config_grid.append(config)

# number of runs for each config combination
runs = 2

# %%
dataset = DigitsDataset(csv_file="../../../data/photonic_QGAN/optdigits_csv.csv", transform = transforms.Compose([transforms.ToTensor()]))
sampler = RandomSampler(dataset, replacement=True, num_samples=batch_size * opt_iter_num)
dataloader = torch.utils.data.DataLoader(
    dataset, batch_size=batch_size, drop_last=True, sampler=sampler
)

# %%
config_grid
# Out:
# [{'input_state': [0, 1, 0, 1, 0],
#   'gen_count': 4,
#   'pnr': False,
#   'noise_dim': 3,
#   'arch': ['var', 'enc[0]', 'var', 'enc[2]', 'var', 'enc[4]', 'var']},
#  {'input_state': [1, 0, 1, 0, 1],
#   'gen_count': 2,
#   'pnr': True,
#   'noise_dim': 3,
#   'arch': ['var', 'enc[0]', 'var', 'enc[2]', 'var', 'enc[4]', 'var']}]

# %%
path = "./ideal/"

if os.path.isdir(path):
    shutil.rmtree(path)

for config_num, config in enumerate(
    #tqdm(config_grid, desc="config", position=0, leave=False)
    tqdm(config_grid, desc="config", position=0)
):
    config_path = f"{path}config_{config_num}"
    os.makedirs(config_path, exist_ok=True)

    with open(os.path.join(config_path, "config.json"), "w") as f:
        f.write(json.dumps(config))

    gen_arch = config["arch"]
    noise_dim = config["noise_dim"]
    input_state = config["input_state"]
    pnr = config["pnr"]
    gen_count = config["gen_count"]

    run_num = 0
    # several runs to average over
    #for i in tqdm(range(1000), desc="run", position=1, leave=False):
    #    if run_num == runs:
    #        break
    #    run_num += 1

    for run_num in tqdm(range(1, runs + 1), desc="run", position=1, leave=False):
        save_path = f"{config_path}/run_{run_num}"
        os.makedirs(save_path, exist_ok=True)

        qgan = QGAN(
            image_size,
            gen_count,
            gen_arch,
            input_state,
            noise_dim,
            batch_size,
            pnr,
            lossy
        )

        iter_pbar = tqdm(
            total=len(dataloader),
            desc="iter",
            position=2,
            leave=False
        )

        def iter_callback(*args, **kwargs):
            iter_pbar.update(1)
            if iter_pbar.n % 10 == 0:
                iter_pbar.refresh()

        try:
            (
                D_loss_progress,
                G_loss_progress,
                G_params_progress,
                fake_data_progress,
            ) = qgan.fit(
                #tqdm(dataloader, desc="iter", position=2, leave=False),
                dataloader,
                lrD,
                lrG,
                opt_params,
                silent=True,
                callback=iter_callback,
            )

            if write_to_disk:
                # fake_data_progress is list of [B,D] tensors/arrays
                arr = np.stack([np.asarray(x) for x in fake_data_progress], axis=0)
                np.save(os.path.join(save_path, "fake_progress.npy"), arr)
                
                # G_params_progress is final_G_params (state_dict)
                torch.save(G_params_progress, os.path.join(save_path, "G_final.pt"))

                # Loss progress
                np.savetxt(
                    os.path.join(save_path, "loss_progress.csv"),
                    np.array(np.array([D_loss_progress, G_loss_progress]).transpose()),
                    delimiter=",",
                    header="D_loss, G_loss",
                )


        except Exception as exc:
            print(exc)
            shutil.rmtree(save_path)
            run_num -= 1

        finally:
            iter_pbar.close()
# Out:
# config:   0%|          | 0/2 [00:00<?, ?it/s]
# run:   0%|          | 0/2 [00:00<?, ?it/s]
# iter:   0%|          | 0/1500 [00:00<?, ?it/s]
# iter:   0%|          | 0/1500 [00:00<?, ?it/s]
# run:   0%|          | 0/2 [00:00<?, ?it/s]
# iter:   0%|          | 0/1500 [00:00<?, ?it/s]
# iter:   0%|          | 0/1500 [00:00<?, ?it/s]

# %%
print(len(D_loss_progress), len(G_loss_progress))
# Out:
# 1500 1500
