# %% [markdown]
# ## Import des Librairies

# %%
import matplotlib.pyplot as plt
import numpy as np
import perceval as pcvl
import sklearn.svm
import torch
from tqdm.notebook import tqdm
from sklearn.decomposition import PCA
import merlin
import os
import sys
from pathlib import Path

# %% [markdown]
# ## Class result
#
# Utile pour garder les résultats, pas sûr que ce soit vraiment la meilleure manière de faire

# %%
class result():
    def __init__(self, g, var_FQK, var_RBF, var_RBF_order_2, F,eta_max, ROC_AUC):
        self.var_FQK = var_FQK
        self.var_RBF = var_RBF
        self.var_RBF_order_2 = var_RBF_order_2
        self.g = g
        self.F = F
        self.eta_max = eta_max
        self.ROC_AUC = ROC_AUC

# %% [markdown]
# ## Préprocessing

# %% [markdown]
# ### Importation du dataset

# %%
def charger_npz_torch(chemin_fichier, est_image=True):
    """
    Charge un fichier .npz et le convertit en tenseur PyTorch.
    """
    # 1. Chargement de l'archive NumPy
    archive = np.load(chemin_fichier)
   
    # Les fichiers .npz sont comme des dictionnaires. On récupère le premier tableau.
    nom_tableau = archive.files[0]
    donnees_np = archive[nom_tableau]
   
    # 2. Conversion en tenseur PyTorch
    tenseur = torch.from_numpy(donnees_np)
   
    # 3. Formatage spécifique selon que ce soit une image ou un label
    if est_image:
        # Conversion en float32, normalisation (0 à 1) et ajout du canal (B, 1, H, W)
        tenseur = tenseur.float() / 255.0
        tenseur = tenseur.unsqueeze(1)
    else:
        # Forçage en type Long pour les labels
        tenseur = tenseur.long()
       
    return tenseur

# --- CONFIGURATION DES CHEMINS ---
# Remplacez toujours la partie tronquée par votre vrai nom de dossier
dossier_plasticc = os.path.join(
    'data',
    'Importance-of-Kernel-Bandwidth-in-Quantum-Machine-Learning', 
    'data',
    'plasticc_data'
)

# Noms exacts d'après votre capture d'écran
chemin_fichier_npy = os.path.join(dossier_plasticc, 'SN_67floats_preprocessed.npy')

# --- CHARGEMENT DES DONNÉES ---
donnes = np.load(chemin_fichier_npy)
tenseur_plasticc = torch.from_numpy(donnes).float()
X_plasticc = tenseur_plasticc[:, :-1]  # Toutes les colonnes sauf la dernière
y_plasticc = tenseur_plasticc[:, -1].long()  # La dernière colonne comme labels

# --- VÉRIFICATION ---
print("--- Chargement de PLAsTiCC Data ---")
print(f"tenseur_plasticc : {tenseur_plasticc.shape} | Type : {tenseur_plasticc.dtype}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 31
#      27
#      28
#      29 # Noms exacts d'après votre capture d'écran
#      30 # --- CHARGEMENT DES DONNÉES ---
# ---> 31 donnes = np.load("Users/TancredeTONINI/Documents/GitHub/reproduced_papers/data/Bandwidth_tunning/plasticc_data/SN_67floats_preprocessed.npy")
#      32 tenseur_plasticc = torch.from_numpy(donnes).float()
#      33 X_plasticc = tenseur_plasticc[:, :-1]  # Toutes les colonnes sauf la dernière
#      34 y_plasticc = tenseur_plasticc[:, -1].long()  # La dernière colonne comme labels
#
# File c:\Users\TancredeTONINI\Documents\GitHub\reproduced_papers\.venv\Lib\site-packages\numpy\lib\_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Users/TancredeTONINI/Documents/GitHub/reproduced_papers/data/Bandwidth_tunning/plasticc_data/SN_67floats_preprocessed.npy'

# %% [markdown]
# ### Reduction du Dataset + PCA

# %%
def subset_PCA(X_train, y_train, X_test, y_test, nb_train, nb_test, dim = -1, seed = 42):
    """Extrait un sous-ensemble des données et applique PCA pour réduire la dimensionnalité."""
    
    torch.manual_seed(seed)  # Pour la reproductibilité
    
    indices_train = torch.randperm(X_train.size(0))[:nb_train]
    indices_test = torch.randperm(X_test.size(0))[:nb_test]
   
    X_train_subset = X_train[indices_train].view(nb_train, -1).numpy()  # Aplatir les images
    y_train_subset = y_train[indices_train]
    X_test_subset = X_test[indices_test].view(nb_test, -1).numpy()  # Aplatir les images
    y_test_subset = y_test[indices_test]
    
    if dim != -1:
        # Appliquer PCA pour réduire à 'dim' dimensions
        pca = PCA(n_components=dim)
        X_train = pca.fit_transform(X_train_subset)
        X_test = pca.transform(X_test_subset)
    
    return torch.from_numpy(X_train).float(), y_train_subset, torch.from_numpy(X_test).float(), y_test_subset
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Calcul des métriques

# %% [markdown]
# ### Calcul de $g(\textbf{K}_C,\textbf{K}_Q)$

# %%
def matrix_sqrt(A): 
    """ Calcule la racine carrée matricielle d'une matrice symétrique semi-définie positive. """ 
    # Décomposition en valeurs propres (A = V * L * V^T) 
    L, V = torch.linalg.eigh(A)
    # Parfois, les erreurs de précision numérique créent des valeurs propres 
    # très légèrement négatives (ex: -1e-15). On les force à être positives ou nulles. 
    L = torch.clamp(L, min=0.0) 
    # Reconstruction : V * sqrt(L) * V^T 
    return V @ torch.diag(torch.sqrt(L)) @ V.T

def calculate_g(K1, K2): 
    """ Calcule g(K1, K2) avec lambda = 0. """ 
    # 1. Calcul de l'inverse de K2
    # Utilisation de pseudo-inverse (pinv) est plus sûr que inv()
    # car une matrice de noyau (K2) peut avoir un déterminant proche de 0. 
    K2_inv = torch.linalg.pinv(K2)
    # 2. Calcul de la racine carrée matricielle de K1 
    sqrt_K1 = matrix_sqrt(K1) 
    # 3. Produit matriciel central : sqrt(K1) @ K2^-1 @ sqrt(K1) 
    inner_matrix = sqrt_K1 @ K2_inv @ sqrt_K1 
    # 4. Norme spectrale (la plus grande valeur singulière, équivalente à ord=2) 
    spectral_norm = torch.linalg.matrix_norm(inner_matrix, ord=2) 
    # 5. Racine carrée finale de la formule 
    g = torch.sqrt(spectral_norm) 
    return g
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Calcul de $\eta_{max}$

# %%
def calculate_eta_max(K):
    L,V = torch.linalg.eigh(K)
    eta_max = L[-1]
    return eta_max
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Calcul de $F(\textbf{K}_C,\textbf{K}_Q)$

# %%
def calculate_kernel_distance_F(K_C, K_Q):
   """
   Calcule F(K_C, K_Q), la distance relative de Frobenius entre deux matrices de noyau.
   K_C : Tenseur PyTorch représentant la matrice de noyau classique.
   K_Q : Tenseur PyTorch représentant la matrice de noyau quantique.
   """
   # 1. Calcul du numérateur : Norme de Frobenius de la différence
   numerateur = torch.linalg.matrix_norm(K_C - K_Q, ord='fro')

   # 2. Calcul du dénominateur : Norme de Frobenius de K_Q
   denominateur = torch.linalg.matrix_norm(K_Q, ord='fro')

   # 3. Ratio final
   F = numerateur / denominateur

   return F
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Fonction d'entrainement de modèle

# %%
def train(X_train, y_train_1D, X_test, y_test_1D, bandwidth = 1.0, n_modes = -1, redundancy = False):

    X_train = X_train * bandwidth
    X_test = X_test * bandwidth

    if n_modes == -1:
        n_modes = X_train.shape[1] + 1
    if n_modes < X_train.shape[1] + 1:
        raise ValueError(f"n_modes must be at least {X_train.shape[1] + 1} for the given input size.")


    builder = merlin.CircuitBuilder(n_modes=n_modes)
    builder.add_entangling_layer(trainable=True, model="mzi", name="left")
    builder.add_angle_encoding(modes=[i for i in range(X_train.shape[1])], name="phi")
    builder.add_entangling_layer(trainable=True, model="mzi", name="right")
    
    feature_map = merlin.FeatureMap(builder=builder, input_size=4, input_parameters="phi")

    fidelity_kernel = merlin.FidelityKernel(
        feature_map=feature_map,
        input_state=[1 - (i % 2) for i in range(n_modes)],  # alternating photons for n_modes
        computation_space=merlin.ComputationSpace.FOCK,
    )
    
    svc = sklearn.svm.SVC(kernel="precomputed")

    K_train = fidelity_kernel(X_train)
    K_test = fidelity_kernel(X_test, X_train)


    svc.fit(K_train.detach().numpy(), y_train_1D.detach().numpy())

    #Calcul du kernel RBF
    distances = torch.cdist(X_train, X_train, p=2)
    distances_carré = distances ** 2
    K_rbf = torch.exp(-distances_carré)

    #Calcul du kernel RBF ordre 2
    distances = torch.cdist(X_train, X_train, p=2)
    z = distances ** 2
    K_rbf_order_2 = 1.0 - z + 0.5*(z**2)


    F = calculate_kernel_distance_F(K_train, K_rbf)
    eta_max = calculate_eta_max(K_train)
    ROC_AUC = sklearn.metrics.roc_auc_score(y_test_1D.detach().numpy(), svc.decision_function(K_test.detach().numpy()))

    return result(calculate_g(K_train,K_rbf).item(), K_train.var(correction=False).item(), K_rbf.var(correction=False).item(), K_rbf_order_2.var(correction=False).item(), F.item(), eta_max.item(), ROC_AUC)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Bandwidths (logarithmically spaced)
MIN,MAX,NB_Points = -3,3,60

# Stockage des résultats pour chaque métrique
x,y_g,y_FQK,y_RBF,y_RBF_order_2,y_F,y_eta_max,y_ROC_AUC = np.logspace(MIN, MAX, NB_Points),np.zeros(NB_Points),np.zeros(NB_Points),np.zeros(NB_Points),np.zeros(NB_Points),np.zeros(NB_Points),np.zeros(NB_Points),np.zeros(NB_Points)

# Size of the training and testing datasets
NB_TRAIN = 320
NB_TEST = 80

#SEEDS (for reproducibility)
SEEDS = [1, 19, 42, 67, 100, 2036]
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
for seed in SEEDS:
    print(f"\n--- Seed: {seed} ---")
    X_train, y_train, X_test, y_test = subset_PCA(X_train, y_train, X_test, y_test, nb_train=NB_TRAIN, nb_test=NB_TEST, dim = 4, seed = seed)
    for i in range(NB_Points):
        res = train(X_train, y_train, X_test, y_test, bandwidth=x[i])
        y_g[i] += res.g
        y_FQK[i] += res.var_FQK
        y_RBF[i] += res.var_RBF
        y_RBF_order_2[i] += res.var_RBF_order_2
        y_F[i] += res.F
        y_eta_max[i] += res.eta_max
        y_ROC_AUC[i] += res.ROC_AUC
# Out:
# --- Seed: 1 ---
#   0%|          | 0/60 [00:00<?, ?it/s]
# --- Seed: 19 ---
#   0%|          | 0/60 [00:00<?, ?it/s]
# --- Seed: 42 ---
#   0%|          | 0/60 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[113], line 5
#       1 for seed in SEEDS:
#       2     print(f"\n--- Seed: {seed} ---")
#       3     X_train, y_train, X_test, y_test = subset_PCA(X_train, y_train, X_test, y_test, nb_train=NB_TRAIN, nb_test=NB_TEST, dim = 4, seed = seed)
#       4     for i in tqdm(range(NB_Points)):
# ----> 5         res = train(X_train, y_train, X_test, y_test, bandwidth=x[i])
#       6         y_g[i] += res.g
#       7         y_FQK[i] += res.var_FQK
#       8         y_RBF[i] += res.var_RBF
#
# Cell In[111], line 28, in train(X_train, y_train_1D, X_test, y_test_1D, bandwidth, n_modes, redundancy)
#      24
#      25     svc = sklearn.svm.SVC(kernel="precomputed")
#      26
#      27     K_train = fidelity_kernel(X_train)
# ---> 28     K_test = fidelity_kernel(X_test, X_train)
#      29
#      30
#      31     svc.fit(K_train.detach().numpy(), y_train_1D.detach().numpy())
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\merlin\algorithms\kernels.py:2121, in FidelityKernel.forward(self, x1, x2)
#    2114 if x2 is None:
#    2115     return self._quantum_layer(
#    2116         x1,
#    2117         shots=self.shots,
#    2118         sampling_method=self.sampling_method,
#    2119     )
# -> 2121 return self._quantum_layer(
#    2122     x1,
#    2123     x2,
#    2124     shots=self.shots,
#    2125     sampling_method=self.sampling_method,
#    2126 )
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\merlin\algorithms\kernels.py:1672, in _CCInvQuantumLayer.forward(self, shots, sampling_method, simultaneous_processes, *input_parameters)
#    1670 len_x1 = len(x1)
#    1671 if x2 is not None:
# -> 1672     transition_probs = self._compute_transition_probs_for_inputs(
#    1673         x1,
#    1674         x2,
#    1675         effective_shots,
#    1676         effective_sampling_method,
#    1677     )
#    1678 else:
#    1679     if len_x1 < 2:
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\merlin\algorithms\kernels.py:1527, in _CCInvQuantumLayer._compute_transition_probs_for_inputs(self, x1, x2, shots, sampling_method)
#    1507 """Compute transition probabilities for input pairs, including phase noise.
#    1508
#    1509 Parameters
#    (...)   1524     Transition probabilities for all computed input pairs.
#    1525 """
#    1526 if not self.computation_process._has_phase_error():
# -> 1527     all_circuits = self._compute_all_kernel_circuits(x1, x2)
#    1528     return self._compute_transition_probs(
#    1529         all_circuits,
#    1530         self._kernel_input_state,
#    1531         shots,
#    1532         sampling_method,
#    1533     )
#    1535 accumulated: Tensor | None = None
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\merlin\algorithms\kernels.py:1471, in _CCInvQuantumLayer._compute_all_kernel_circuits(self, x1, x2, apply_phase_error)
#    1443 def _compute_all_kernel_circuits(
#    1444     self,
#    1445     x1: Tensor,
#    (...)   1448     apply_phase_error: bool = False,
#    1449 ) -> Tensor:
#    1450     """Compute composed kernel unitaries for all requested input pairs.
#    1451
#    1452     Parameters
#    (...)   1469         ``(N * (N - 1) / 2, m, m)``.
#    1470     """
# -> 1471     U_forward = self._compute_unitary_batch(
#    1472         x1,
#    1473         apply_phase_error=apply_phase_error,
#    1474     ).to(x1.device)
#    1476     if x2 is not None:
#    1477         U_adjoint = (
#    1478             self
#    1479             ._compute_unitary_batch(
#    (...)   1485             .to(x1.device)
#    1486         )
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\merlin\algorithms\kernels.py:1436, in _CCInvQuantumLayer._compute_unitary_batch(self, x_batch, apply_phase_error)
#    1418 """Compute a batch of circuit unitaries.
#    1419
#    1420 Parameters
#    (...)   1431     Stacked unitary tensor of shape ``(N, m, m)``.
#    1432 """
#    1433 # Serial loop is intentional: CircuitConverter.to_tensor holds shared
#    1434 # mutable state and is not safe to call concurrently.
#    1435 return torch.stack([
# -> 1436     self._compute_unitary(
#    1437         self._encode_single(x),
#    1438         apply_phase_error=apply_phase_error,
#    1439     )
#    1440     for x in x_batch
#    1441 ])
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\merlin\algorithms\kernels.py:1372, in _CCInvQuantumLayer._compute_unitary(self, x_enc, apply_phase_error)
#    1351 def _compute_unitary(
#    1352     self,
#    1353     x_enc: Tensor,
#    1354     *,
#    1355     apply_phase_error: bool = False,
#    1356 ) -> Tensor:
#    1357     """Evaluate the circuit unitary for an already-encoded input.
#    1358
#    1359     Parameters
#    (...)   1370         Complex unitary matrix of shape ``(m, m)``.
#    1371     """
# -> 1372     return self.computation_process.converter.to_tensor(
#    1373         *self.thetas,
#    1374         x_enc,
#    1375         apply_phase_error=apply_phase_error,
#    1376     )
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\merlin\pcvl_pytorch\locirc_to_tensor.py:641, in CircuitConverter.to_tensor(self, batch_size, apply_phase_error, memristive_current_state, *input_params)
#     637     curr_comp_tensor = c.to(
#     638         dtype=self.tensor_cdtype, device=self.device
#     639     ).expand(batch_size, -1, -1)
#     640 else:
# --> 641     curr_comp_tensor = self._compute_tensor(c)
#     643 # Compose unitaries
#     644 contribution = converted_tensor[..., r[0] : (r[-1] + 1), :].clone()
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\multipledispatch\dispatcher.py:439, in MethodDispatcher.__call__(self, *args, **kwargs)
#     434 if not func:
#     435     raise NotImplementedError(
#     436         "Could not find signature for %s: <%s>"
#     437         % (self.name, str_signature(types))
#     438     )
# --> 439 return func(self.obj, *args, **kwargs)
#
# File c:\Users\TancredeTONINI\Documents\Merlin\env\Lib\site-packages\merlin\pcvl_pytorch\locirc_to_tensor.py:855, in CircuitConverter._compute_tensor(self, comp)
#     849     phase_error = torch.empty_like(phase).uniform_(
#     850         -phase_error_half_width,
#     851         phase_error_half_width,
#     852     )
#     853     phase = phase + phase_error
# --> 855 unitary_tensor = torch.exp(1j * phase.to(self.tensor_cdtype)).reshape(
#     856     -1, 1
#     857 )  # reshape so that in any case, we have 2 dim
#     858 return unitary_tensor.unsqueeze(-1)
#
# KeyboardInterrupt:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
y_g_avg = y_g / len(SEEDS)
y_FQK_avg = y_FQK / len(SEEDS)
y_RBF_avg = y_RBF / len(SEEDS)
y_RBF_order_2_avg = y_RBF_order_2 / len(SEEDS)
y_F_avg = y_F / len(SEEDS)
y_eta_max_avg = y_eta_max / len(SEEDS)
y_ROC_AUC_avg = y_ROC_AUC / len(SEEDS)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Affichage des résultats

# %%
# Création de la figure et d'une grille de 6 graphiques
# figsize=(15, 5) permet d'avoir une image bien large
fig, axes = plt.subplots( 2, 3, figsize=(15, 10))

# ==========================================
# Subplot 1 : Les Variances (FQK et RBF)
# ==========================================
axes[0,0].loglog(x, y_FQK_avg, label="FQK", marker='o', linestyle='-')
axes[0,0].loglog(x, y_RBF, label="RBF", marker='s', linestyle='-')

axes[0,0].set_title("Variances des noyaux")
axes[0,0].set_xlabel(r"Bandwidth $c$")
axes[0,0].set_ylabel(r"$Var_D[\mathbf{K}]$")
axes[0,0].legend() # Affiche la légende pour différencier les 3 courbes
axes[0,0].grid(True, which="both", ls="--", alpha=0.5) # Ajoute une grille lisible en log

# ==========================================
# Subplot 2 : La métrique g
# ==========================================
axes[0,1].loglog(x, y_g_avg, color='purple', marker='d', linestyle='-')

axes[0,1].set_title(r"Métrique $g$")
axes[0,1].set_xlabel(r"Bandwidth $c$")
axes[0,1].set_ylabel(r"$g(\mathbf{K}_C, \mathbf{K}_Q)$")
axes[0,1].grid(True, which="both", ls="--", alpha=0.5)

# ==========================================
# Subplot 3 : La distance F
# ==========================================
axes[1,0].loglog(x, y_F_avg, color='green', marker='v', linestyle='-')

axes[1,0].set_title("Distance de Frobenius")
axes[1,0].set_xlabel(r"Bandwidth $c$")
axes[1,0].set_ylabel(r"$F(\mathbf{K}_C, \mathbf{K}_Q)$")
axes[1,0].grid(True, which="both", ls="--", alpha=0.5)

# ==========================================
# Subplot 4 : eta_max
# ==========================================
axes[1,1].loglog(x, y_eta_max_avg, color='orange', marker='^', linestyle='-')

axes[1,1].set_title(r"$\eta_{max}$")
axes[1,1].set_xlabel(r"Bandwidth $c$")
axes[1,1].set_ylabel(r"$\eta_{max(K)}$")
axes[1,1].grid(True, which="both", ls="--", alpha=0.5)


# ==========================================
# Subplot 5 : ROC AUC
# ==========================================
axes[0,2].semilogx(x, y_ROC_AUC_avg, color='red', marker='s', linestyle='-')

axes[0,2].set_title(r"ROC AUC score")
axes[0,2].set_xlabel(r"Bandwidth $c$")
axes[0,2].set_ylabel("roc auc score")
axes[0,2].grid(True, which="both", ls="--", alpha=0.5)

# ==========================================
# Subplot 6 : VAR(RBF_order_2)
# ==========================================
axes[1,2].loglog(x, y_RBF_order_2_avg, color='blue', marker='x', linestyle='-')

axes[1,2].set_title("Variance du noyau RBF (ordre 2)")
axes[1,2].set_xlabel(r"Bandwidth $c$")
axes[1,2].set_ylabel("Variance")
axes[1,2].grid(True, which="both", ls="--", alpha=0.5)

# ==========================================
# Affichage propre
# ==========================================
fig.suptitle(r"kMNIST28 $(N = , PCA = 4, Seeds = 5)$")
# tight_layout empêche les titres et les labels de se chevaucher
plt.tight_layout() 
plt.show()
# Out:
# C:\Users\TancredeTONINI\AppData\Local\Temp\ipykernel_27220\384854681.py:73: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.tight_layout()
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(y_g_avg[-1])
# Out:
# 0.0
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
